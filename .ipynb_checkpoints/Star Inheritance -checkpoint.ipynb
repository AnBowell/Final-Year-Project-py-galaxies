# %% [markdown]
# <center><h1>Py-Galaxies examples</h1></center>

# %% [markdown]
# # SUB-HALO Stars

# %% [markdown]
# ## Import modules

# %%
from PyGalaxies import Parameters, Monitor, HDF_graph_properties, Halos
import time
import numpy as np


model_param_filepath='Input_Params/input_params.yml'
debug_flag = False
verbosity = 1 
time_code = True

# %% [markdown]
# ## Get model params and print

# %%
model_params = Parameters.ModelParams(model_param_filepath,verbosity,debug_flag)
model_params.output_params()
# Out:
# input_files         : {'graph_file': '../Input Data/mega_graph_mini_09-11.hdf5'}
# output_files        : {'halo_file': '../Output Data/SMT13HaloOutput.hdf5', 'galaxy_file': '../Output Data/SMT13GalaxyOutput.hdf5'}
# cosmology           : {'omega_m': {'Description': 'Matter density parameter', 'Value': 0.3, 'Units': 'None'}, 'f_baryon': {'Description': 'Baryon fraction', 'Value': 0.155, 'Units': 'None'}}
# model_switches      : {'HOD': {'Description': 'Halo occupation description for stars (as primitive test)', 'Value': True}, 'sub_halo': {'Description': 'For each graph, load in Sub-halo data?', 'Value': True}}
# performance         : {'io_nRec': {'Description': 'Size of HDF5 io buffer (number of records)', 'Value': 1000}}
# Monitoring          : {'Timing': {'Description': 'Whether or not to time parts of code and save output', 'Value': True, 'graph_save_path': 'Graph_Outputs/Timing/', 'timing_data_save_path': 'Monitoring Data/'}}

# %% [markdown]
# ## Run main routine

# %%
# Open the input HDF5 file containing graph groups and create an output file.
HDF_properties = HDF_graph_properties.HDFProperties(model_params)



start_time = time.time()


graph_arrays = []
graph_lengths = [] 
n_halo_in_graph = []


for graph_ID in range(0,HDF_properties.no_of_graphs)[:]:

    if verbosity >= 2: print('Processing graph',graph_ID)
    

    graph_properties = HDF_graph_properties.GraphProperties(graph_ID,
                                       HDF_properties.graph_input_file,
                                       model_params,
                                       HDF_properties.part_mass)

    
    array_of_halo_properties = np.empty(len(graph_properties.graph_halo_ids),
                                        dtype = object)
    
    if type(graph_properties.n_subhalos) == int:
        graph_lengths.append(np.nan)
        continue
    else:
        n_halo_in_graph.append(graph_properties.n_halos_in_graph)
        graph_lengths.append(np.sum(graph_properties.n_subhalos))
    
    for snap_ID in graph_properties.generation_id:
        

        if graph_properties.generation_start_index[snap_ID] == 2**30:
            continue
    
        
        this_generation_halo = graph_properties.graph_halo_ids[
                               graph_properties.generation_start_index[snap_ID]:
                               graph_properties.generation_start_index[snap_ID] + 
                               graph_properties.generation_length[snap_ID]]
        
        for halo_ID in this_generation_halo:
            
            halo = Halos.HaloProperties(str(graph_ID), snap_ID, halo_ID,
                                  graph_properties, HDF_properties.part_mass,
                                  HDF_properties.dtype_subhalo_stores)
            

            halo.halo_descendent_props()

            halo.calc_halo_DM_descend(HDF_properties.part_mass)

            halo.calc_halo_attrs_descend(HDF_properties.part_mass, array_of_halo_properties,
                                         HDF_properties.halo_descend_attrs)

            halo.set_baryon_fraction(array_of_halo_properties, model_params.f_baryon)

            
            halo.collect_galaxy_prog_info(graph_properties, HDF_properties, array_of_halo_properties)

            
            halo.add_baryon_mass()

            
            #halo.add_stellar_mass() # Adds on Berhoozi top up

            
            halo.calculate_infall(model_params.f_baryon)
        
            halo.done = True
            
            array_of_halo_properties[halo_ID] = halo

            HDF_properties.n_halo +=1 

    # Save output
    HDF_properties.output_halos(array_of_halo_properties)

    graph_arrays.append(array_of_halo_properties)


# Close input file
HDF_properties.close_graph_io(HDF_properties.graph_input_file)


# Close output files
if HDF_properties.halo_output_iRec > 0: 

    halo_output_iRec = HDF_properties.flush_output()
    
HDF_properties.close_graph_io(HDF_properties.halo_output_file)


end_time = time.time()
print('This took {} seconds'.format(end_time-start_time))
# Out:
# This took 41.905550718307495 seconds

# %%
vars(array_of_halo_properties[-1])
# Out:
# {'graph_ID': '975',
#  'snap_ID': 61,
#  'halo_ID': 22,
#  'catalog_ID': 1816,
#  'mass': 39903177160.09238,
#  'nprog': 1,
#  'prog_start': 21,
#  'prog_end': 22,
#  'prog_ids': array([21]),
#  'prog_mass': array([3.99031772e+10]),
#  'ndesc': -1,
#  'desc_start': 1073741824,
#  'desc_end': 1073741823,
#  'desc_ids': array([], dtype=int32),
#  'desc_mass': array([], dtype=float64),
#  'mean_pos': array([33.91094678, 50.83798803, 36.65987155]),
#  'velocity_dispersion_3D': 37.06783550241392,
#  'mean_vel': array([-305.18989563,   60.86648401,  142.69911067]),
#  'rms_radius': 0.044236223452654815,
#  'redshift': 4.440892098500626e-16,
#  'total_halo_stellar_mass': 0.0,
#  'hot_gas': array([23.]),
#  'cold_gas': array([46.]),
#  'ejected_gas': array([69.]),
#  'mass_baryon': array([6.18499249e+09]),
#  'mass_from_progenitors': 5.307545158232393e+19,
#  'mass_baryon_from_progenitors': 0.0,
#  'inclusive_contribution': array([], dtype=float64),
#  'done': True,
#  'subhalo_start_index': 9,
#  'n_subhalo': 1,
#  'sub_halo_attrs': array([(9, 3.89219978e+19, 10., False, 0.)],
#        dtype=[('sub_graph_ids', '<i4'), ('prog_DM_mass', '<f8'), ('stellar_mass', '<f8'), ('descended', '?'), ('SFR', '<f8')]),
#  'sub_graph_halo_ids': array([9]),
#  'central_galaxy_ID': 9}

# %%
for i in range(0,23):
    print(vars(array_of_halo_properties[i])['hot_gas'], 'hot gas')
    print(vars(array_of_halo_properties[i])['cold_gas'], 'cold gas')
    print(vars(array_of_halo_properties[i])['hot_gas'], 'ejected gas')
# Out:
# 1.0 hot gas
# 1.0 cold gas
# 1.0 ejected gas
# [2.] hot gas
# [2.] cold gas
# [2.] ejected gas
# [3.] hot gas
# [3.] cold gas
# [3.] ejected gas
# [4.] hot gas
# [4.] cold gas
# [4.] ejected gas
# [5.] hot gas
# [5.] cold gas
# [5.] ejected gas
# [6.] hot gas
# [6.] cold gas
# [6.] ejected gas
# [7.] hot gas
# [7.] cold gas
# [7.] ejected gas
# [8.] hot gas
# [8.] cold gas
# [8.] ejected gas
# [9.] hot gas
# [9.] cold gas
# [9.] ejected gas
# [10.] hot gas
# [10.] cold gas
# [10.] ejected gas
# [11.] hot gas
# [11.] cold gas
# [11.] ejected gas
# [12.] hot gas
# [12.] cold gas
# [12.] ejected gas
# [13.] hot gas
# [13.] cold gas
# [13.] ejected gas
# [14.] hot gas
# [14.] cold gas
# [14.] ejected gas
# [15.] hot gas
# [15.] cold gas
# [15.] ejected gas
# [16.] hot gas
# [16.] cold gas
# [16.] ejected gas
# [17.] hot gas
# [17.] cold gas
# [17.] ejected gas
# [18.] hot gas
# [18.] cold gas
# [18.] ejected gas
# [19.] hot gas
# [19.] cold gas
# [19.] ejected gas
# [20.] hot gas
# [20.] cold gas
# [20.] ejected gas
# [21.] hot gas
# [21.] cold gas
# [21.] ejected gas
# [22.] hot gas
# [22.] cold gas
# [22.] ejected gas
# [23.] hot gas
# [23.] cold gas
# [23.] ejected gas

# %%
import matplotlib.pyplot as plt
test_graphs = np.arange(0,697,1) 
save = True

# %%
fig, ax = plt.subplots(figsize=(12,8))


snaps = np.arange(0,62)

final_mass_ratios = []

for graph in test_graphs:
    snapshot_mass = []
    gen_counter = 0
    
    graph_lengths = np.array(graph_lengths)
        
    graph_lengths = graph_lengths[~np.isnan(graph_lengths)] 
    
    this_graph_length = graph_lengths[graph]
    
    #print(this_graph_length)
    
    for snapshot in range(0,62):

        halos_classes = graph_arrays[graph]
        running_mass = 0 
        
        for halo_counter, halo_class in enumerate(halos_classes):

            if halo_class.n_subhalo > 0:
                 
                if halo_class.snap_ID == snapshot:
                    
                    running_mass += np.sum(halo_class.sub_halo_attrs['stellar_mass']) / (this_graph_length)

                    
                    
        snapshot_mass.append(running_mass)
    final_mass_ratios.append(running_mass)
        
    ax.plot(snaps,snapshot_mass)
    
ax.grid(True, alpha= 0.6)

ax.set_ylabel('Stellar Mass / Total Intial Stellar Mass')
ax.set_xlabel('Snapshot')

if save:
    plt.savefig('..\Output Data\TestMass Fraction Plot.jpg',dpi = 400)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(12, 8))
ax1.scatter(n_halo_in_graph,final_mass_ratios)
ax1.grid(True, alpha= 0.6)
ax1.set_xscale('log')
ax1.set_ylabel('Final snapshot stellar mass fraction')
ax1.set_xlabel('n_halo')
plt.savefig('..\Output Data\FinalStellarFraction.jpg',dpi = 400)
plt.show()

# %%
halo_param_file ='input_params/halo_plot_params.yml'
plot_halos = Halos.PlotHalos(halo_param_file) # Loads in params and filters

plot_halos.generate_plots()
